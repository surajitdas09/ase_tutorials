# %% [markdown]
# ### Introduction

# %%
# ! pip3 install ase 
import ase 
print(ase.__version__)
# Out:
# 3.22.1

# %%
# ! pip install nglview
from ase.visualize import view

# %%
# ! pip install gpaw
from gpaw import GPAW, PW

# %% [markdown]
# #### Today's Menu
# <ul>
#     <li> 02_Atoms </li>
#     <li> 03_molecules </li>
#     <li> 04_bulk </li>
#     <li> 05_structure_optimization </li>
#     <li> 06_dft </li>
#     <li> 07_dihedral.py </li>
# </ul>

# %% [markdown]
# #### In Future
# <ul>
#     <li> Calculator (in details) </li>
#     <li> Molecular Dynamics </li>
#     <li> Constrains </li>
#     <li> Minimum energy path </li>
#     <li> Vibrational analysis & Phonon calculation </li>
# </ul>

# %% [markdown]
# #### Reference:
# Hjorth et al., <i>The atomic simulation environment—a Python library for working with atoms</i>,
# J. Phys.: Condens. Matter.,
# 2017, <b>29</b>(27), 273002.
# <br> DOI: <url>10.1088/1361-648X/aa680e</url>
#
# #### For ASE documentation:
# <url>https://ase-lib.org/about.html</url>
