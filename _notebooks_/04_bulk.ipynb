# %%
from ase.io import write
from ase.visualize import view

# %% [markdown]
# ## <i><b> from ase.build import bulk </b></i>

# %%
from ase.build import bulk

# %%
au = bulk('Au', 'fcc', a=4.08)
write('../_files_/pbc_au.cif', au) # --- cif file

# write('../_files_/POSCAR', au) # --- POSCAR format
# write('au.traj', au) # --- ASE native trajectory

# %%
fe = bulk('Fe', 'bcc', a=2.87)

# %%
si = bulk('Si', 'diamond', a=5.43)

# %% [markdown]
# #### Supercell <i><b> repeat() </b></i>

# %%
au_super = au.repeat((3, 3, 3))
write('../_files_/pbc_au_3x3x3.cif', au_super)

# %% [markdown]
# #### <i><b> fcc111 </b></i>

# %%
from ase.build import fcc111

cu_surface = fcc111('Cu', size=(3,3,3))

# %%
view(cu_surface, viewer='ngl')
